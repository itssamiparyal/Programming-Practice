# %%
import pandas as pd

# %%
df = pd.read_csv('train_and_test2.csv')

# %%
df.Age
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304    28.0
# 1305    39.0
# 1306    38.5
# 1307    28.0
# 1308    28.0
# Name: Age, Length: 1309, dtype: float64

# %%
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
type(df.Age)
# Out:
# pandas.core.series.Series

# %%
df['Age']
# Out:
# 0       22.0
# 1       38.0
# 2       26.0
# 3       35.0
# 4       35.0
#         ...
# 1304    28.0
# 1305    39.0
# 1306    38.5
# 1307    28.0
# 1308    28.0
# Name: Age, Length: 1309, dtype: float64

# %%
df[['Age','Fare','Sex']]
# Out:
#        Age      Fare  Sex
# 0     22.0    7.2500    0
# 1     38.0   71.2833    1
# 2     26.0    7.9250    1
# 3     35.0   53.1000    1
# 4     35.0    8.0500    0
# ...    ...       ...  ...
# 1304  28.0    8.0500    0
# 1305  39.0  108.9000    1
# 1306  38.5    7.2500    0
# 1307  28.0    8.0500    0
# 1308  28.0   22.3583    0
#
# [1309 rows x 3 columns]

# %%
df[['Age']]
# Out:
#        Age
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# ...    ...
# 1304  28.0
# 1305  39.0
# 1306  38.5
# 1307  28.0
# 1308  28.0
#
# [1309 rows x 1 columns]

# %%
df.Age.mean()
# Out:
# 29.50318563789152

# %%
df.Sex.mode()
# Out:
# 0    0
# Name: Sex, dtype: int64

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Sex.mode().iloc[0]
# Out:
# 0

# %%
df.Fare.min()
# Out:
# 0.0

# %%
df.Fare.max()
# Out:
# 512.3292

# %%
df.Fare.mean()
# Out:
# 33.28108563789152

# %%
df
# Out:
#       Passengerid   Age      Fare  Sex  sibsp  zero  zero.1  zero.2  zero.3  \
# 0               1  22.0    7.2500    0      1     0       0       0       0
# 1               2  38.0   71.2833    1      1     0       0       0       0
# 2               3  26.0    7.9250    1      0     0       0       0       0
# 3               4  35.0   53.1000    1      1     0       0       0       0
# 4               5  35.0    8.0500    0      0     0       0       0       0
# ...           ...   ...       ...  ...    ...   ...     ...     ...     ...
# 1304         1305  28.0    8.0500    0      0     0       0       0       0
# 1305         1306  39.0  108.9000    1      0     0       0       0       0
# 1306         1307  38.5    7.2500    0      0     0       0       0       0
# 1307         1308  28.0    8.0500    0      0     0       0       0       0
# 1308         1309  28.0   22.3583    0      1     0       0       0       0
#
# ...

# %%
df['2urvived'].mode()
# Out:
# 0    0
# Name: 2urvived, dtype: int64

# %%
df['2urvived'].mode().iloc[0]
# Out:
# 0

# %%
(df['2urvived']== 0).sum()
# Out:
# 967

# %%
(df['2urvived']== 1).sum()
# Out:
# 342

# %%
((df['2urvived'] == 0) & (df.Sex == 0)).sum()
# Out:
# 734

# %%
((df['2urvived'] == 1) & (df.Sex == 0)).sum()
# Out:
# 109

# %%
((df['2urvived'] == 0) & (df.Sex == 1)).sum()
# Out:
# 233

# %%
((df['2urvived'] == 1) & (df.Sex == 1)).sum()
# Out:
# 233

# %%
df =pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Embarked.mode()
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
(df.Embarked == 'S').sum()
# Out:
# 644

# %%
df.Age.min()
# Out:
# 0.42

# %%
df.Age.max()
# Out:
# 80.0

# %%
((df.Age >= 35) & (df.Age <= 70) & (df.Sex == 'male')).sum()
# Out:
# 149

# %%
((df.Sex == 'male')&(df.Age)).mean()
# Out:
# 0.5084175084175084

# %%
((df.Sex == 'female')&(df.Age)).mean()
# Out:
# 0.29292929292929293

# %%
df_male = df[df.Sex == 'male']

# %%
df_male.Age.mean()
# Out:
# 30.72664459161148

# %%
df_female = df[df.Sex == 'female']

# %%
df_female.Age.mean()
# Out:
# 27.915708812260537
