# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
pd.Series(5)
# Out:
# 0    5
# dtype: int64

# %%
pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3], dtype='int16')
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int16

# %%
pd.Series(10, index=['a'])
# Out:
# a    10
# dtype: int64

# %%
pd.Series([3,4,5,6], index=['a','b','c','d'])
# Out:
# a    3
# b    4
# c    5
# d    6
# dtype: int64

# %%
pd.Series([3,4,5,6], index=['a','b','a','b'])
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
pd.NA

# %%
a = pd.Series([1,2,3,pd.NA,pd.NA])

# %%
a
# Out:
# 0       1
# 1       2
# 2       3
# 3    <NA>
# 4    <NA>
# dtype: object

# %%
a+5
# Out:
# 0       6
# 1       7
# 2       8
# 3    <NA>
# 4    <NA>
# dtype: object

# %%
a = pd.Series([1,2,3])
b = pd.Series([4,5,6])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
b
# Out:
# 0    4
# 1    5
# 2    6
# dtype: int64

# %%
a+b
# Out:
# 0    5
# 1    7
# 2    9
# dtype: int64

# %%
a = pd.Series([1,2,3])
b = pd.Series([4,5,6,7])

# %%
a+b
# Out:
# 0    5.0
# 1    7.0
# 2    9.0
# 3    NaN
# dtype: float64

# %%
my_series = pd.Series([3,4,5,6], index=['a','b','a','b'])

# %%
my_series
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
my_series.index
# Out:
# Index(['a', 'b', 'a', 'b'], dtype='object')

# %%
my_series.values
# Out:
# array([3, 4, 5, 6], dtype=int64)

# %%
my_series.dtype
# Out:
# dtype('int64')

# %%
my_series.shape
# Out:
# (4,)

# %%
my_series.size
# Out:
# 4

# %%
my_series.nbytes
# Out:
# 32

# %%
my_series.ndim
# Out:
# 1

# %%
my_series.T
# Out:
# a    3
# b    4
# a    5
# b    6
# dtype: int64

# %%
my_series.memory_usage()
# Out:
# 236

# %%
my_series.hasnans
# Out:
# False

# %%
a = pd.Series([1,2,3,4, pd.NA])

# %%
a.hasnans
# Out:
# True

# %%
a.empty
# Out:
# False

# %%
a = pd.Series([])

# %%
a.empty
# Out:
# True

# %%
import pandas as pd

# %%
a = pd.Series([1,2,3,4,5])

# %%
a.dtype
# Out:
# dtype('int64')

# %%
a.astype('float')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# dtype: float64

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
b = pd.Series([1.1,2.8,3.6])

# %%
b = b.astype('int')

# %%
b
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int32

# %%
a.min()
# Out:
# 1

# %%
a.max()
# Out:
# 5

# %%
a.mean()
# Out:
# 3.0

# %%
a.median()
# Out:
# 3.0

# %%
a.std()
# Out:
# 1.5811388300841898

# %%
a.var()
# Out:
# 2.5

# %%
a.mode()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
a = pd.Series([8,6,3,0,5,2])

# %%
a.sort_values()
# Out:
# 3    0
# 5    2
# 2    3
# 4    5
# 1    6
# 0    8
# dtype: int64

# %%
a
# Out:
# 0    8
# 1    6
# 2    3
# 3    0
# 4    5
# 5    2
# dtype: int64

# %%
a.sort_values(inplace = True)

# %%
a
# Out:
# 3    0
# 5    2
# 2    3
# 4    5
# 1    6
# 0    8
# dtype: int64
