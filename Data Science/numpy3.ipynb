# %%
import numpy as np

# %%
arr = np.array([[1,2,3,4],[2,4,6,8],[1,3,5,7],[6,9,5,9],[6,7,8,9]])

# %%
arr[4,::2]
# Out:
# array([6, 8])

# %%
a = np.array(input("enter name:"))
# Out:
# enter name: 1
