# %%
import numpy as np

# %% [markdown]
# ## Declaration of array

# %%
a = np.array([1,2,3,4])

# %%
a
# Out:
# array([1, 2, 3, 4])

# %%
b = np.array ([1,2,3.0])

# %%
b
# Out:
# array([1., 2., 3.])

# %%
np.array([1.0,2.0,3.0],dtype ='int')
# Out:
# array([1, 2, 3])
